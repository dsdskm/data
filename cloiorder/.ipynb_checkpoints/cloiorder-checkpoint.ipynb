# %% [markdown]
# # 초기화

# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime

#plt.rc("font", family="Malgun Gothic")
plt.rc("font", family="AppleGothic")
plt.rcParams.update({'font.size': 22})
# 데이터로드
df = pd.read_csv("inroomdinning_Orderlist_2023-1_2023-12.csv",encoding="utf-8")
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
pd.set_option("display.float_format","{:,}".format)

# %% [markdown]
# # 데이터 전처리

# %%
# 공백제거
df["카테고리"]=df["카테고리"].replace(" ","")
df["카테고리"]=df["카테고리"].str.strip()
df["상품명"]=df["상품명"].replace(" ","")
df["상품명"]=df["상품명"].str.strip()

# 컬럼명 변경
df = df.rename(columns={'합계':'매출'})

df["주문 일시"] = pd.to_datetime(df["주문 일시"],format="%Y.%m.%d %H:%M:%S",errors="raise")
df["년"] = df["주문 일시"].dt.year
df["월"] = df["주문 일시"].dt.month
df["일"] = df["주문 일시"].dt.day
df["요일"] = df["주문 일시"].dt.day_of_week
#weekday_list = ['월', '화', '수', '목', '금', '토', '일']
#df['요일'] = df.apply(lambda x : weekday_list[x['요일']], axis = 1)
#df['요일_Index'] = df["주문 일시"].dt.day_of_week
df["시"] = df["주문 일시"].dt.hour
df["분"] = df["주문 일시"].dt.minute

df.head()
# Out:
#                  ID               주문 일시   결제 금액           카테고리  \
# 0  2311190366810549 2023-11-19 13:06:51   32000       점심/인룸다이닝
# 1  2311190366585450 2023-11-19 13:03:06  127000  안주&후식류/ 인룸다이닝
# 2  2311190366585450 2023-11-19 13:03:06  127000  안주&후식류/ 인룸다이닝
# 3  2311190366585450 2023-11-19 13:03:06  127000       점심/인룸다이닝
# 4  2311190366585450 2023-11-19 13:03:06  127000       점심/인룸다이닝
#
#                  상품명  상품 가격  수량     매출     년   월   일  요일   시  분
# 0          김치찌개 (점심)  32000   1  32000  2023  11  19   6  13  6
# 1              키위 주스  14000   1  14000  2023  11  19   6  13  3
# 2           낙지볶음과 소면  66000   1  66000  2023  11  19   6  13  3
# 3            공기밥(점심)   2000   1   2000  2023  11  19   6  13  3
# 4  한우 버섯 불고기 정식 (점심)  45000   1  45000  2023  11  19   6  13  3

# %% [markdown]
# # (년/월/일/요일/시간대) 총 매출

# %% [markdown]
# ## 1) 년도별 총 매출

# %%
sum_year_total_data = pd.DataFrame(df.groupby(["년"],as_index=False)["매출"].sum())
ax=plt.gca()
ax.get_yaxis().get_major_formatter().set_scientific(False)
sns.barplot(x="년",y="매출",data=sum_year_total_data)
sum_year_total_data
# Out:
#       년         매출
# 0  2023  155278500

# %% [markdown]
# ## 2) 월별 총 매출

# %%
sum_month_total_data = pd.DataFrame(df.groupby(["월"],as_index=False)["매출"].sum())
ax=plt.gca()
ax.get_yaxis().get_major_formatter().set_scientific(False)
sns.barplot(x="월",y="매출",data=sum_month_total_data)
# Out:
# <Axes: xlabel='월', ylabel='매출'>

# %% [markdown]
# ## 일별 총 매출

# %%
sum_date_total_data = pd.DataFrame(df.groupby(["일"],as_index=False)["매출"].sum())
plt.figure(figsize=(20,10))
ax=plt.gca()
ax.get_yaxis().get_major_formatter().set_scientific(False)
p = sns.barplot(x="일",y="매출",data=sum_date_total_data)

# %% [markdown]
# ## 3) 요일별 총 매출

# %%
sum_day_total_data = pd.DataFrame(df.groupby(["요일"],as_index=False)["매출"].sum())
weekday_list = ['월', '화', '수', '목', '금', '토', '일']
sum_day_total_data['요일'] = sum_day_total_data.apply(lambda x : weekday_list[x['요일']], axis = 1)
ax=plt.gca()
ax.get_yaxis().get_major_formatter().set_scientific(False)
sns.barplot(x="요일",y="매출",data=sum_day_total_data)
sum_day_total_data.sum()
# Out:
# 요일      월화수목금토일
# 매출    155278500
# dtype: object

# %% [markdown]
# ## 4) 시간대 별 총 매출

# %%
sum_time_total_data = pd.DataFrame(df.groupby(["시"],as_index=False)["매출"].sum())
plt.figure(figsize=(20,10))
ax=plt.gca()
ax.get_yaxis().get_major_formatter().set_scientific(False)
sns.barplot(x="시",y="매출",data=sum_time_total_data)
# Out:
# <Axes: xlabel='시', ylabel='매출'>

# %% [markdown]
# ## 5) 연도 및 카테고리별 총 매출

# %%
sum_year_category_total_data = pd.DataFrame(df.groupby(["년","카테고리"],as_index=False)["매출"].sum())
sum_year_category_total_data = sum_year_category_total_data.sort_values("매출")
plt.figure(figsize=(50,10))

ax=plt.gca()
ax.get_yaxis().get_major_formatter().set_scientific(False)
sns.barplot(x="카테고리",y="매출",data=sum_year_category_total_data)
# Out:
# <Axes: xlabel='카테고리', ylabel='매출'>

# %% [markdown]
# ## 6) 월별 및 카테고리별 총 매출

# %%
sum_month_category_total_data = pd.DataFrame(df.groupby(["월","카테고리"],as_index=False)["매출"].sum())
sum_month_category_total_data = sum_month_category_total_data.sort_values("월")
fig = plt.figure(figsize=(100,50))

area01 = fig.add_subplot(4,3,1)
area01.set_title("1월 카테고리별 매출")
area02 = fig.add_subplot(4,3,2)
area02.set_title("2월 카테고리별 매출")
area03 = fig.add_subplot(4,3,3)
area03.set_title("3월 카테고리별 매출")

area04 = fig.add_subplot(4,3,4)
area04.set_title("4월 카테고리별 매출")
area05 = fig.add_subplot(4,3,5)
area05.set_title("5월 카테고리별 매출")
area06 = fig.add_subplot(4,3,6)
area06.set_title("6월 카테고리별 매출")

area07 = fig.add_subplot(4,3,7)
area07.set_title("7월 카테고리별 매출")
area08 = fig.add_subplot(4,3,8)
area08.set_title("8월 카테고리별 매출")
area09 = fig.add_subplot(4,3,9)
area09.set_title("9월 카테고리별 매출")

area10 = fig.add_subplot(4,3,10)
area10.set_title("10월 카테고리별 매출")
area11 = fig.add_subplot(4,3,11)
area11.set_title("11월 카테고리별 매출")


area01.get_yaxis().get_major_formatter().set_scientific(False)
area02.get_yaxis().get_major_formatter().set_scientific(False)
area03.get_yaxis().get_major_formatter().set_scientific(False)
area04.get_yaxis().get_major_formatter().set_scientific(False)
area05.get_yaxis().get_major_formatter().set_scientific(False)
area06.get_yaxis().get_major_formatter().set_scientific(False)
area07.get_yaxis().get_major_formatter().set_scientific(False)
area08.get_yaxis().get_major_formatter().set_scientific(False)
area09.get_yaxis().get_major_formatter().set_scientific(False)
area10.get_yaxis().get_major_formatter().set_scientific(False)
area11.get_yaxis().get_major_formatter().set_scientific(False)

sum_month_category_total_data_01 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==1]
sum_month_category_total_data_01 = sum_month_category_total_data_01.sort_values("매출")
sum_month_category_total_data_02 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==2]
sum_month_category_total_data_02 = sum_month_category_total_data_02.sort_values("매출")
sum_month_category_total_data_03 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==3]
sum_month_category_total_data_03 = sum_month_category_total_data_03.sort_values("매출")
sum_month_category_total_data_04 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==4]
sum_month_category_total_data_04 = sum_month_category_total_data_04.sort_values("매출")
sum_month_category_total_data_05 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==5]
sum_month_category_total_data_04 = sum_month_category_total_data_05.sort_values("매출")
sum_month_category_total_data_06 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==6]
sum_month_category_total_data_06 = sum_month_category_total_data_06.sort_values("매출")
sum_month_category_total_data_07 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==7]
sum_month_category_total_data_07 = sum_month_category_total_data_07.sort_values("매출")
sum_month_category_total_data_08 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==8]
sum_month_category_total_data_08 = sum_month_category_total_data_08.sort_values("매출")
sum_month_category_total_data_09 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==9]
sum_month_category_total_data_09 = sum_month_category_total_data_09.sort_values("매출")
sum_month_category_total_data_10 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==10]
sum_month_category_total_data_10 = sum_month_category_total_data_10.sort_values("매출")
sum_month_category_total_data_11 = sum_month_category_total_data.loc[sum_month_category_total_data['월']==11]
sum_month_category_total_data_11 = sum_month_category_total_data_11.sort_values("매출")


sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_01,ax=area01)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_02,ax=area02)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_03,ax=area03)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_04,ax=area04)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_05,ax=area05)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_06,ax=area06)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_07,ax=area07)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_08,ax=area08)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_09,ax=area09)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_10,ax=area10)
sns.barplot(x="카테고리",y="매출",data=sum_month_category_total_data_11,ax=area11)
# Out:
# <Axes: title={'center': '11월 카테고리별 매출'}, xlabel='카테고리', ylabel='매출'>
